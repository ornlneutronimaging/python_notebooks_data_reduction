# %% [markdown]
# # Table of contents

# %% [markdown]
# * [normalization with simplify selection](normalization_with_simplify_selection.ipynb)
# * [normalization for TOF data](normalization_tof.ipynb)
# * [normalization for Resonance mode](normalization_resonance.ipynb)
